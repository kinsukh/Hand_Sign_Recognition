# %%
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (4.22.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.9.0 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.9.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2022.9.13)
# Requirement already satisfied: numpy>=1.17 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (1.22.2)
# Requirement already satisfied: requests in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: filelock in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: colorama in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (1.26.10)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed

# %%
# import torch
# torch.set_default_tensor_type(torch.cuda.FloatTensor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <module>
#       1 import torch
# ----> 2 torch.set_default_tensor_type(torch.cuda.FloatTensor)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:331, in set_default_tensor_type(t)
#     329 if isinstance(t, _string_classes):
#     330     t = _import_dotted_name(t)
# --> 331 _C._set_default_tensor_type(t)
#
# TypeError: type torch.cuda.FloatTensor not available. Torch not compiled with CUDA enabled.

# %%
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b7", use_cache=True)
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b7")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:837, in _create_relative_symlink(src, dst)
#     836 try:
# --> 837     os.symlink(relative_src, dst)
#     838 except OSError:
#     839     # Likely running on Windows
#
# OSError: [WinError 1314] A required privilege is not held by the client: '..\\..\\blobs\\42a31e9851cd235248f4cd8a14fd0039ecefbcf9' -> 'C:\\Users\\Kinsukh/.cache\\huggingface\\hub\\models--bigscience--bloom-1b7\\snapshots\\9c4abbee769fb8b99f401d8f4289304bead4b922\\config.json'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b7", use_cache=True)
#       2 tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b7")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\auto\auto_factory.py:434, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     432 hub_kwargs = {name: kwargs.pop(name) for name in hub_kwargs_names if name in kwargs}
#     433 if not isinstance(config, PretrainedConfig):
# --> 434     config, kwargs = AutoConfig.from_pretrained(
#     435         pretrained_model_name_or_path,
#     436         return_unused_kwargs=True,
#     437         trust_remote_code=trust_remote_code,
#     438         **hub_kwargs,
#     439         **kwargs,
#     440     )
#     441 if hasattr(config, "auto_map") and cls.__name__ in config.auto_map:
#     442     if not trust_remote_code:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\auto\configuration_auto.py:746, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     744 kwargs["name_or_path"] = pretrained_model_name_or_path
#     745 trust_remote_code = kwargs.pop("trust_remote_code", False)
# --> 746 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     747 if "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]:
#     748     if not trust_remote_code:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\configuration_utils.py:553, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     551 original_kwargs = copy.deepcopy(kwargs)
#     552 # Get config dict associated with the base config file
# --> 553 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     554 if "_commit_hash" in config_dict:
#     555     original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\configuration_utils.py:608, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     604 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME)
#     606 try:
#     607     # Load from local folder or from cache or download from model Hub and cache
# --> 608     resolved_config_file = cached_file(
#     609         pretrained_model_name_or_path,
#     610         configuration_file,
#     611         cache_dir=cache_dir,
#     612         force_download=force_download,
#     613         proxies=proxies,
#     614         resume_download=resume_download,
#     615         local_files_only=local_files_only,
#     616         use_auth_token=use_auth_token,
#     617         user_agent=user_agent,
#     618         revision=revision,
#     619         subfolder=subfolder,
#     620         _commit_hash=commit_hash,
#     621     )
#     622     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     623 except EnvironmentError:
#     624     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted to
#     625     # the original exception.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\hub.py:408, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     405 user_agent = http_user_agent(user_agent)
#     406 try:
#     407     # Load from URL or cache if already cached
# --> 408     resolved_file = hf_hub_download(
#     409         path_or_repo_id,
#     410         filename,
#     411         subfolder=None if len(subfolder) == 0 else subfolder,
#     412         revision=revision,
#     413         cache_dir=cache_dir,
#     414         user_agent=user_agent,
#     415         force_download=force_download,
#     416         proxies=proxies,
#     417         resume_download=resume_download,
#     418         use_auth_token=use_auth_token,
#     419         local_files_only=local_files_only,
#     420     )
#     422 except RepositoryNotFoundError:
#     423     raise EnvironmentError(
#     424         f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     425         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to "
#     426         "pass a token having permission to this repo with `use_auth_token` or log in with "
#     427         "`huggingface-cli login` and pass `use_auth_token=True`."
#     428     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:1218, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, use_auth_token, local_files_only, legacy_cache_layout)
#    1215 if os.path.exists(blob_path) and not force_download:
#    1216     # we have the blob already, but not the pointer
#    1217     logger.info("creating pointer to %s from %s", blob_path, pointer_path)
# -> 1218     _create_relative_symlink(blob_path, pointer_path)
#    1219     return pointer_path
#    1221 # Prevent parallel downloads of the same file with a lock.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:841, in _create_relative_symlink(src, dst)
#     838 except OSError:
#     839     # Likely running on Windows
#     840     if os.name == "nt":
# --> 841         raise OSError(
#     842             "Windows requires Developer Mode to be activated, or to run Python as "
#     843             "an administrator, in order to create symlinks.\nIn order to "
#     844             "activate Developer Mode, see this article: "
#     845             "https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development"
#     846         )
#     847     else:
#     848         raise
#
# OSError: Windows requires Developer Mode to be activated, or to run Python as an administrator, in order to create symlinks.
# In order to activate Developer Mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development

# %%
set_seed(424242)

# %%
model.__class__.__name__

# %%
def make_sentence(prompt,max_length):
  input_ids = tokenizer(prompt, return_tensors="pt").to(0)
  sample = model.generate(**input_ids, max_length=max_length,  top_k=1, temperature=0.9, repetition_penalty = 2.0)
  print(tokenizer.decode(sample[0], truncate_before_pattern=[r"\n\n^#", "^'''", "\n\n\n"]))

# %%
make_sentence('sql in dbms',50)
