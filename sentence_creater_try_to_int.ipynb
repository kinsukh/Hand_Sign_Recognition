# %%
# !pip install transformers

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed

# %%
import torch
torch.set_default_tensor_type(torch.cuda.FloatTensor)

# %%
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b7", use_cache=True)
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b7")
# Out:
# Downloading:   0%|          | 0.00/710 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/222 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
set_seed(424242)

# %%
model.__class__.__name__
# Out:
# 'BloomForCausalLM'

# %%
def make_sentence(prompt,max_length):
  input_ids = tokenizer(prompt, return_tensors="pt").to(0)
  sample = model.generate(**input_ids, max_length=max_length,  top_k=1, temperature=0.9, repetition_penalty = 2.0)
  print(tokenizer.decode(sample[0], truncate_before_pattern=[r"\n\n^#", "^'''", "\n\n\n"]))

# %%
make_sentence('hi',50)
# Out:
# hi, and the other two were in their late teens. The three men had been drinking heavily at a bar on Saturday night.
# The police said they arrested one of them after he was found to be carrying an illegal firearm with him inside his car
