# %%
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (4.22.1)
# Requirement already satisfied: filelock in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2022.9.13)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: requests in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (1.22.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.9.0 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.9.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: colorama in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kinsukh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (1.26.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed

# %%
import torch
torch.set_default_tensor_type(torch.cuda.FloatTensor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\VITB_SEM_3_FALL_SEM_22_23\PJ_exhibition\main project\sentence_creater.ipynb Cell 3 in <module>
#       <a href='vscode-notebook-cell:/d%3A/VITB_SEM_3_FALL_SEM_22_23/PJ_exhibition/main%20project/sentence_creater.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import torch
# ----> <a href='vscode-notebook-cell:/d%3A/VITB_SEM_3_FALL_SEM_22_23/PJ_exhibition/main%20project/sentence_creater.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> torch.set_default_tensor_type(torch.cuda.FloatTensor)
#
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:331, in set_default_tensor_type(t)
#     329 if isinstance(t, _string_classes):
#     330     t = _import_dotted_name(t)
# --> 331 _C._set_default_tensor_type(t)
#
# TypeError: type torch.cuda.FloatTensor not available. Torch not compiled with CUDA enabled.

# %%
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b7", use_cache=True)
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b7")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\modeling_utils.py:371, in load_state_dict(checkpoint_file)
#     370 try:
# --> 371     return torch.load(checkpoint_file, map_location="cpu")
#     372 except Exception as e:
#
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:705, in load(f, map_location, pickle_module, **pickle_load_args)
#     704 orig_position = opened_file.tell()
# --> 705 with _open_zipfile_reader(opened_file) as opened_zipfile:
#     706     if _is_torchscript_zip(opened_zipfile):
#
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:242, in _open_zipfile_reader.__init__(self, name_or_buffer)
#     241 def __init__(self, name_or_buffer) -> None:
# --> 242     super(_open_zipfile_reader, self).__init__(torch._C.PyTorchFileReader(name_or_buffer))
#
# RuntimeError: PytorchStreamReader failed reading zip archive: failed finding central directory
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\modeling_utils.py:375, in load_state_dict(checkpoint_file)
#     374 with open(checkpoint_file) as f:
# --> 375     if f.read().startswith("version"):
#     376         raise OSError(
#     377             "You seem to have cloned a repository without having git-lfs installed. Please install "
#     378             "git-lfs and run `git lfs install` followed by `git lfs pull` in the folder "
#     379             "you cloned."
#     380         )
#
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1603: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# d:\VITB_SEM_3_FALL_SEM_22_23\PJ_exhibition\main project\sentence_creater.ipynb Cell 4 in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/VITB_SEM_3_FALL_SEM_22_23/PJ_exhibition/main%20project/sentence_creater.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b7", use_cache=True)
#       <a href='vscode-notebook-cell:/d%3A/VITB_SEM_3_FALL_SEM_22_23/PJ_exhibition/main%20project/sentence_creater.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b7")
#
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\auto\auto_factory.py:463, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     461 elif type(config) in cls._model_mapping.keys():
#     462     model_class = _get_model_class(config, cls._model_mapping)
# --> 463     return model_class.from_pretrained(
#     464         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     465     )
#     466 raise ValueError(
#     467     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     468     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     469 )
#
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\modeling_utils.py:2110, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2107 if from_pt:
#    2108     if not is_sharded and state_dict is None:
#    2109         # Time to load the checkpoint
# -> 2110         state_dict = load_state_dict(resolved_archive_file)
#    2112     # set dtype to instantiate the model under:
#    2113     # 1. If torch_dtype is not None, we use that dtype
#    2114     # 2. If torch_dtype is "auto", we auto-detect dtype from the loaded state_dict, by checking its first
#    2115     #    weights entry that is of a floating type - we assume all floating dtype weights are of the same dtype
#    2116     # we also may have config.torch_dtype available, but we won't rely on it till v5
#    2117     dtype_orig = None
#
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\modeling_utils.py:387, in load_state_dict(checkpoint_file)
#     382             raise ValueError(
#     383                 f"Unable to locate the file {checkpoint_file} which is necessary to load this pretrained "
#     384                 "model. Make sure you have saved the model properly."
#     385             ) from e
#     386 except (UnicodeDecodeError, ValueError):
# --> 387     raise OSError(
#     388         f"Unable to load weights from pytorch checkpoint file for '{checkpoint_file}' "
#     389         f"at '{checkpoint_file}'. "
#     390         "If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True."
#     391     )
#
# OSError: Unable to load weights from pytorch checkpoint file for 'C:\Users\Kinsukh/.cache\huggingface\hub\models--bigscience--bloom-1b7\snapshots\9c4abbee769fb8b99f401d8f4289304bead4b922\pytorch_model.bin' at 'C:\Users\Kinsukh/.cache\huggingface\hub\models--bigscience--bloom-1b7\snapshots\9c4abbee769fb8b99f401d8f4289304bead4b922\pytorch_model.bin'. If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True.

# %%
set_seed(424242)

# %%
model.__class__.__name__

# %%
def make_sentence(prompt,max_length):
  input_ids = tokenizer(prompt, return_tensors="pt").to(0)
  sample = model.generate(**input_ids, max_length=max_length,  top_k=1, temperature=0.9, repetition_penalty = 2.0)
  print(tokenizer.decode(sample[0], truncate_before_pattern=[r"\n\n^#", "^'''", "\n\n\n"]))

# %%
make_sentence('sql in dbms',50)
