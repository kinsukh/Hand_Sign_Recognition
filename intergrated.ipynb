# %%
import import_ipynb
import sentence_creater
# Out:
# importing Jupyter notebook from sentence_creater.ipynb
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\Kinsukh\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:837, in _create_relative_symlink(src, dst)
#     836 try:
# --> 837     os.symlink(relative_src, dst)
#     838 except OSError:
#     839     # Likely running on Windows
#
# OSError: [WinError 1314] A required privilege is not held by the client: '..\\..\\blobs\\42a31e9851cd235248f4cd8a14fd0039ecefbcf9' -> 'C:\\Users\\Kinsukh/.cache\\huggingface\\hub\\models--bigscience--bloom-1b7\\snapshots\\9c4abbee769fb8b99f401d8f4289304bead4b922\\config.json'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ...
